# %% [markdown]
# # Chapter 3 - Magnetic field around a conductor

# %% [markdown]
# ### Exercise 9

# %% [markdown]
# ### Exercise 10

# %% [markdown]
# ### Exercise 11

# %% [markdown]
# ### Exercise 12

# %% [markdown]
# ### Exercise 13

# %%
from sympy import *
from dtumathtools import *

y,x,r = symbols('y,x,r')

mu_0=4*pi*10**-7
I=1

e_theta = Matrix([-y, x])*1/sqrt(x**2+y**2)
B_theta = (mu_0)*I/(2*pi*r)
B = Matrix([0, B_theta])
B = B_theta.subs({r:sqrt(x**2+y**2)})*e_theta
dtuplot.plot_vector(B, (x,0-100,100),(y,-100,100),scalar=False, quiver_kw={"color":"black"}, grid=False, colorbar=False, use_cm=True, n=(20,20))
display(B)
# Out:
# Matrix([
# [-2.0e-7*y/(x**2 + y**2)],
# [ 2.0e-7*x/(x**2 + y**2)]])

# %%
from sympy import *
from dtumathtools import *

y,x,r = symbols('y,x,r')

mu_0=4*pi*10**-7
I=1

B = Matrix([-y*mu_0*I, x*mu_0*I])/(2*pi*(x**2+y**2))
dtuplot.plot_vector(B, (x,0-100,100),(y,-100,100),scalar=False, quiver_kw={"color":"black"}, grid=False, colorbar=False, use_cm=True, n=(20,20))
display(B)
# Out:
# Matrix([
# [-2.0e-7*y/(x**2 + y**2)],
# [ 2.0e-7*x/(x**2 + y**2)]])
